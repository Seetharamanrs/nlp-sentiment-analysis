# %% [markdown]
# ## Preparing data

# %% [markdown]
# ### Train Data

# %%
from pathlib import Path
dataset_path_pos=Path("../data/train/pos")
dataset_path_neg=Path("../data/train/neg")

# %%
pos_files = list(dataset_path_pos.glob("*.txt"))
neg_files = list(dataset_path_neg.glob("*.txt"))
print(len(pos_files))
# Out:
# 12500

# %%
sample_file=pos_files[0]
text=sample_file.read_text(encoding='utf-8')
print(text[:100])
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life,

# %%
# Reading all the Review from the .txt file 
def read_review(files): 
    reviews=[]
    for file in files:
        text=file.read_text(encoding='utf-8')
        reviews.append(text)
    return reviews

# %%
pos_review=read_review(pos_files)

# %%
neg_review=read_review(neg_files)

# %%
# The data is stored in list with the review type
def store_data(reviews,rev_type):
    data=[]
    for review in reviews:
        data.append({"review": review,
                    "sentiment":rev_type})
    return data

# %%
pos_data=store_data(pos_review,"positive")
neg_data=store_data(neg_review,"negative")

# %%
all_data=pos_data+neg_data

# %%
import pandas as pd 
df= pd.DataFrame(all_data)

# %%
df=df.sample(frac=1,random_state=42).reset_index(drop=True)

# %%
df
# Out:
#                                                   review sentiment
# 0      Bromwell High is a cartoon comedy. It ran at t...  positive
# 1      Homelessness (or Houselessness as George Carli...  positive
# 2      Brilliant over-acting by Lesley Ann Warren. Be...  positive
# 3      This is easily the most underrated film inn th...  positive
# 4      This is not the typical Mel Brooks film. It wa...  positive
# ...                                                  ...       ...
# 24995  Towards the end of the movie, I felt it was to...  negative
# 24996  This is the kind of movie that my enemies cont...  negative
# 24997  I saw 'Descent' last night at the Stockholm Fi...  negative
# 24998  Some films that you pick up for a pound turn o...  negative
# 24999  This is one of the dumbest films, I've ever se...  negative
#
# [25000 rows x 2 columns]

# %%
df.head()
# Out:
#                                               review sentiment
# 0  Bromwell High is a cartoon comedy. It ran at t...  positive
# 1  Homelessness (or Houselessness as George Carli...  positive
# 2  Brilliant over-acting by Lesley Ann Warren. Be...  positive
# 3  This is easily the most underrated film inn th...  positive
# 4  This is not the typical Mel Brooks film. It wa...  positive

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    12500
# negative    12500
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#                                                   review sentiment
# 15165  Being a big fan of the "other" PLANET OF THE A...  negative
# 7764   Ray Liotta and Tom Hulce shine in this sterlin...  positive
# 4123   Kenneth Branagh's "Hamlet" hits all the marks....  positive
# 7468   Barbara Stanwyck as a real tough cookie, a wai...  positive
# 1104   I've seen this movie at theater when it first ...  positive
# 24460  OK, I have watched the original French version...  negative
# 15611  I honestly don't understand how tripe like thi...  negative
# 19747  ***SPOILERS*** ***SPOILERS*** When I saw a pre...  negative
# 13910  I rented this thinking it might be interesting...  negative
# 19224  I give this marriage 3 years and thats stretch...  negative

# %%
df.to_csv("../data/train.csv")

# %% [markdown]
# ### Test Data

# %%
dataset_path_test_pos=Path("../data/test/pos")
dataset_path_test_neg=Path("../data/test/neg")

# %%
test_pos=list(dataset_path_test_pos.glob("**.txt"))
test_neg=list(dataset_path_test_neg.glob("**.txt"))

# %%
test_pos_review=read_review(test_pos)

# %%
test_neg_review=read_review(test_neg)

# %%
test_data_pos=store_data(test_pos_review,"positive")
test_data_neg=store_data(test_neg_review,"negative")

# %%
all_test_data=test_data_pos+test_data_neg

# %%
test_df=pd.DataFrame(all_test_data)

# %%
test_df=test_df.sample(frac=1,random_state=42).reset_index(drop=True)

# %%
test_df.head()
# Out:
#                                               review sentiment
# 0  When I was a kid, I loved "Tiny Toons". I espe...  positive
# 1  The setup for "Nature of the Beast" is ingenio...  negative
# 2  I do not have much to say than this is a great...  positive
# 3  Extremely formulaic with cosmic-sized logic ho...  negative
# 4  I actually liked certain things about this gam...  negative

# %%
test_df.to_csv("../data/test.csv")

# %%
sample_review=df["review"][0]
